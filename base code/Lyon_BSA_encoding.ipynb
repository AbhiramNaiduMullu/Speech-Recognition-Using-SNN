# %% [markdown]
# Importing the relevant libraries

# %%
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import tensorflow as tf
import matplotlib.pyplot as plt
import pathlib
import os

# %% [markdown]
# Lyon cochlear model to convert soundwaves to cochlear activations

# %%
pip install lyon
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lyon
#   Downloading lyon-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lyon) (1.21.6)
# Installing collected packages: lyon
# Successfully installed lyon-1.0.0

# %%
pip install pyspikes
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyspikes
#   Downloading pyspikes-0.2.9-py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from pyspikes) (1.0.2)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from pyspikes) (1.7.3)
# Requirement already satisfied: numpy>=1.10.3 in /usr/local/lib/python3.7/dist-packages (from pyspikes) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.0->pyspikes) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.17.0->pyspikes) (3.1.0)
# Installing collected packages: pyspikes
# Successfully installed pyspikes-0.2.9

# %%
from numpy import float64
from lyon.calc import LyonCalc
from librosa import load
from spikes import encoder

# %%
seed=42
tf.random.set_seed(seed)
np.random.seed(seed)

# %%
DATASET_PATH = 'data/mini_speech_commands'
data_dir = pathlib.Path(DATASET_PATH)
if not data_dir.exists():
  tf.keras.utils.get_file(
      'mini_speech_commands.zip',
      origin="http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip",
      extract=True,
      cache_dir='.', cache_subdir='data')
# Out:
# Downloading data from http://storage.googleapis.com/download.tensorflow.org/data/mini_speech_commands.zip
# 182083584/182082353 [==============================] - 3s 0us/step
# 182091776/182082353 [==============================] - 3s 0us/step

# %%
commands = np.array(tf.io.gfile.listdir(str(data_dir)))
commands = commands[commands != 'README.md']
print('Commands:', commands)
# Out:
# Commands: ['left' 'down' 'no' 'yes' 'stop' 'right' 'go' 'up']

# %%
x_train=[]
y_train=[]

for label in commands:
  print(label)
  for filename in os.listdir(os.path.join(DATASET_PATH,label)):
    if (not(filename.endswith('.wav'))):
      continue
    waveform,sample_rate=load(os.path.join(DATASET_PATH,label,filename))
    calc = LyonCalc()
    decimation_factor = 16
    coch = calc.lyon_passive_ear(waveform.astype(float64), sample_rate, decimation_factor)
    samples=np.reshape(coch,[1,coch.shape[0],coch.shape[1]])
    if np.min(samples)<0:
      print(np.min(samples))
    bsa = encoder.BSA(samples)
    spikes = np.int8(bsa.get_spikes())
    x_train.append(spikes)
    y_train.append(label)
# Out:
# left
# down
# no
# yes
# stop
# right
# go
# up

# %%
print(len(x_train))
print(x_train[0].shape)
print(x_train[0].dtype)
# Out:
# 8000
# (1, 2205, 96)
# int8

# %%
m=max([x.shape[1] for x in x_train])
x_train=[np.reshape(np.concatenate((x[0],np.zeros((m-x.shape[1],x.shape[2])))),(x.shape[0],-1,x.shape[2])) for x in x_train]

# %%
import random
temp=list(zip(x_train,y_train))
random.shuffle(temp)
x_train,y_train=zip(*temp)
x_train=list(x_train)
y_train=list(y_train)

# %%
x_data=np.int8(np.concatenate(x_train))
y_data=np.array(y_train)

# %%
print(x_data.shape)
print(y_data.shape)
# Out:
# (8000, 1378, 96)
# (8000,)

# %%
print(x_data.dtype)
# Out:
# int8

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/My Drive/Colab Notebooks/tf_LSM/'
np.save(data_path + 'mini_speech_data_decimation_16', x_data)
np.save(data_path + 'mini_speech_label_decimation_16', y_data)

# %%
test_load_data = np.load(data_path + 'mini_speech_data_decimation_16.npy')
test_load_label = np.load(data_path + 'mini_speech_label_decimation_16.npy')
print(np.max(test_load_data - x_data))
print(np.min(test_load_data - x_data))
# Out:
# 0
# 0

# %%
for i in range(100):
  print('loaded label i: ', test_load_label[i])
  print('original label i: ', y_data[i])
# Out:
# loaded label i:  go
# original label i:  go
# loaded label i:  go
# original label i:  go
# loaded label i:  down
# original label i:  down
# loaded label i:  up
# original label i:  up
# loaded label i:  down
# original label i:  down
# loaded label i:  up
# original label i:  up
# loaded label i:  left
# original label i:  left
# loaded label i:  down
# original label i:  down
# loaded label i:  no
# original label i:  no
# loaded label i:  up
# original label i:  up
# loaded label i:  go
# original label i:  go
# loaded label i:  down
# original label i:  down
# loaded label i:  left
# original label i:  left
# loaded label i:  stop
# original label i:  stop
# loaded label i:  left
# original label i:  left
# loaded label i:  down
# original label i:  down
# loaded label i:  go
# original label i:  go
# loaded label i:  down
# original label i:  down
# loaded label i:  left
# original label i:  left
# loaded label i:  up
# original label i:  up
# loaded label i:  go
# original label i:  go
# loaded label i:  go
# original label i:  go
# loaded label i:  no
# original label i:  no
# loaded label i:  right
# original label i:  right
# loaded label i:  go
# original label i:  go
# loaded label i:  no
# original label i:  no
# loaded label i:  no
# original label i:  no
# loaded label i:  up
# original label i:  up
# loaded label i:  down
# original label i:  down
# loaded label i:  up
# original label i:  up
# loaded label i:  left
# original label i:  left
# loaded label i:  down
# original label i:  down
# loaded label i:  go
# original label i:  go
# loaded label i:  right
# original label i:  right
# loaded label i:  go
# original label i:  go
# loaded label i:  left
# original label i:  left
# loaded label i:  yes
# original label i:  yes
# loaded label i:  go
# original label i:  go
# loaded label i:  up
# original label i:  up
# loaded label i:  no
# original label i:  no
# loaded label i:  up
# original label i:  up
# loaded label i:  go
# original label i:  go
# loaded label i:  up
# original label i:  up
# loaded label i:  no
# original label i:  no
# loaded label i:  right
# original label i:  right
# loaded label i:  go
# original label i:  go
# loaded label i:  no
# original label i:  no
# loaded label i:  no
# original label i:  no
# loaded label i:  up
# original label i:  up
# loaded label i:  go
# original label i:  go
# loaded label i:  go
# original label i:  go
# loaded label i:  no
# original label i:  no
# loaded label i:  left
# original label i:  left
# loaded label i:  stop
# original label i:  stop
# loaded label i:  yes
# original label i:  yes
# loaded label i:  right
# original label i:  right
# loaded label i:  right
# original label i:  right
# loaded label i:  down
# original label i:  down
# loaded label i:  left
# original label i:  left
# loaded label i:  down
# original label i:  down
# loaded label i:  stop
# original label i:  stop
# loaded label i:  up
# original label i:  up
# loaded label i:  no
# original label i:  no
# loaded label i:  go
# original label i:  go
# loaded label i:  stop
# original label i:  stop
# loaded label i:  yes
# original label i:  yes
# loaded label i:  yes
# original label i:  yes
# loaded label i:  go
# original label i:  go
# loaded label i:  right
# original label i:  right
# loaded label i:  up
# original label i:  up
# loaded label i:  left
# original label i:  left
# loaded label i:  stop
# original label i:  stop
# loaded label i:  no
# original label i:  no
# loaded label i:  yes
# original label i:  yes
# loaded label i:  no
# original label i:  no
# loaded label i:  go
# original label i:  go
# loaded label i:  down
# original label i:  down
# loaded label i:  right
# original label i:  right
# loaded label i:  no
# original label i:  no
# loaded label i:  go
# original label i:  go
# loaded label i:  go
# original label i:  go
# loaded label i:  yes
# original label i:  yes
# loaded label i:  down
# original label i:  down
# loaded label i:  no
# original label i:  no
# loaded label i:  go
# original label i:  go
# loaded label i:  left
# original label i:  left
# loaded label i:  no
# original label i:  no
# loaded label i:  right
# original label i:  right
# loaded label i:  yes
# original label i:  yes
# loaded label i:  up
# original label i:  up
# loaded label i:  yes
# original label i:  yes
# loaded label i:  left
# original label i:  left
# loaded label i:  yes
# original label i:  yes
# loaded label i:  left
# original label i:  left
# loaded label i:  left
# original label i:  left
# loaded label i:  up
# original label i:  up
# loaded label i:  right
# original label i:  right
# loaded label i:  go
# original label i:  go
# loaded label i:  left
# original label i:  left
# loaded label i:  down
# original label i:  down

# %%
'''
data_size_test = x_train.shape[0]//5

x_test=np.array(x_train[-data_size_test:])
y_test=np.array(y_train[-data_size_test:])
x_in_train=np.array(x_train[:-data_size_test])
y_in_train=np.array(y_train[:-data_size_test])

data_size = x_in_train.shape[0]
'''
